# %% [markdown]
# <a href="https://colab.research.google.com/github/TrSaleMane/deep-learning-from-step-by-step/blob/main/vol04_env_setup/vol04_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1. Colab の基本操作
#
# Google Colab はブラウザだけで使えるノートブック環境です。
#
# - セルを実行 → 左の「▶」ボタン
# - 新しいセル → 「+ コード」または「+ テキスト」
# - エラーが出たら → セルを再実行 or ランタイム再起動

# %% [markdown]
# ###GPU の確認方法

# %%
import torch

print("GPU が使えるか？:", torch.cuda.is_available())

# %%
if torch.cuda.is_available():
    print("GPU 名:", torch.cuda.get_device_name(0))
else:
    print("GPU は利用できません")

# %% [markdown]
# ## 2. Google Colab を使った講座のノートブックの開き方
#
# ファイル → ノートブックを開く
# GitHub タブを選ぶ
# リポジトリ URL を貼るとノートブック一覧が表示される
#
#
#
# 1.   ブラウザで「Google Colab」と検索
# 2.   Google アカウントでログイン
# 3.   ファイル → ノートブックを開く
# 4.   GitHub タブを選ぶ
# 5.   リポジトリ URL を貼るとノートブック一覧が表示される

# %% [markdown]
# ## 3. ノートブック内の「Open in Colab」ボタン
#
# 講座のGitHub の notebook に、下のGoogle Colabを起動するボタンを設定しています。
#
# ワンクリックで Google Colab を開くことができます。

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](YOUR_COLAB_LINK_HERE)

# %% [markdown]
# ##4.Googleドライブを Colab にマウントする方法
# ノートブックのセルに次のコードを実行します：

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# 実行すると、「Googleアカウントへのアクセス許可」→「認証コードの入力」というステップで進めていきます。
#
# 認証が完了すると、次のようなフォルダが使えるようになります。
#
# /content/drive/MyDrive/

# %% [markdown]
# ##5.Colab に画像ファイルをアップロードする方法（Vol.8 で使用）
# Colabでは、次のコードを実行することでファイルをアップロードできます。

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# 実行すると、画面に「ファイルを選択」ボタンが表示されます。
#
# 手書き数字の画像（例：my_digit.png）を選ぶと、Colab にアップロードできます。

# %% [markdown]
# アップロードされたファイルは次のようにアクセスできます：

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open('my_digit.png')
plt.imshow(img, cmap='gray')
plt.axis('off')

# %% [markdown]
# ##6.Googleドライブに保存している画像ファイルを読み込む
# Googleドライブをマウントしている場合は、あらかじめドライブ内に画像を保存しておけば Colab から直接読み込むことができます。

# %% [markdown]
# 例えば、みなさんのGoogleドライブに、mnistフォルダがあって、その中に、my_digit.pngという画像ファイルがある場合、Colab から直接読み込むことができます。

# %%
img_path = '/content/drive/MyDrive/mnist/my_digit.png'
img = Image.open(img_path)
plt.imshow(img, cmap='gray')
plt.axis('off')

# %% [markdown]
# ## ▶ 次のステップ
#
# Vol.5 では
# **「MNISTを読み込んで可視化してみる」**
# を実際にコードを書きながら学びます。
