# %% [markdown]
# <a href="https://colab.research.google.com/github/TrSaleMane/deep-learning-from-step-by-step/blob/main/vol01_overview/vol01_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # はじめてのディープラーニング：MNISTで学ぶ1日集中講座 Vol.1
#
# ## 🔗 講座の GitHub リポジトリ
# 講座の全ノートブック・資料はこちらにまとめています。
#
# 👉 GitHub:
# https://github.com/TrSaleMane/deep-learning-from-step-by-step
#
# ## 🎯 この講座のゴール
# ディープラーニングの基礎を理解し、MNIST の分類モデルを実装すること。
#
# ## 🗺 学習の流れ（全体像）
# STEP1：ディープラーニングの全体像をつかむ
# - ニューラルネットワークとは
# - 学習とは何をしているのか
# - MNIST で何を解くのか
#
# STEP2：Google Colab の準備
# - Colab の基本操作
# - ノートブックの構成
#
# STEP3：MNIST を使ってモデルを作る
# - データの読み込み
# - ネットワーク構築
# - 学習の実行
# - 精度の確認
#
# ## 🛠 使用ツール
# - Google Colab
# - Python
# - PyTorch
#
# ## 📚 参考書籍
# 『ゼロから作るディープラーニング』（オライリージャパン 斎藤康毅 著）
#
# ## ▶ 次のステップ：Vol.2 へ進む
# Vol.2 では
# 「MNISTとは？なぜ入門に最適なのか？」
# を紹介し、実際にデータを触っていきます。
